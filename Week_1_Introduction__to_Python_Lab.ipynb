# %% [markdown]
# <a href="https://colab.research.google.com/github/rajuiit/OOP-Python-Fall-2020/blob/master/Week_1_Introduction__to_Python_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **My Python First Program "Print HeLLo World"**
#
# ---

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # **Variables and Assignment Statements**
#
# ---

# %%
x=7
y=3
print(x+y)
# Out:
# 10

# %%
total = x+y
print(total)
# Out:
# 10

# %%
name = "Adam"
name2 = "Eva"
print(name , name2)
# Out:
# Adam Eva

# %% [markdown]
# # **Types**
#
# ---

# %%
x =10
type(x)
# Out:
# int

# %%
type(10.5)
# Out:
# float

# %%
type(name)
# Out:
# str

# %% [markdown]
# # **Arithmetic operators**
#
# ---

# %%
 multiplication = 7*4
 print(multiplication)
# Out:
# 28

# %%
add = 10+15
print(add)
# Out:
# 25

# %%
sub = 40-8
print(sub)
# Out:
# 32

# %%
Exponentiation = 2**10
print(Exponentiation)
# Out:
# 1024

# %% [markdown]
# True Division (/) vs. Floor Division (//)

# %%
True_Division = 7/4
print(True_Division)
# Out:
# 1.75

# %%
Floor_Division = 7//4
print(Floor_Division)
# Out:
# 1

# %%
remainder = 15%7
print(remainder)
# Out:
# 1

# %% [markdown]
# # **Relational Operators**
#
# ---

# %%
x = 105
y = 100

# %%
x>y
# Out:
# True

# %%
x<y
# Out:
# False

# %%
x==y
# Out:
# False

# %%
x!=y
# Out:
# True

# %%
x>=y
# Out:
# True

# %%
x<=y
# Out:
# False

# %% [markdown]
# Chaining Comparisons

# %%
x = 3
y = 10

# %%
1 <= x <= 5
# Out:
# True

# %%
1 <= y <= 5
# Out:
# False

# %% [markdown]
# # **Print Function**
#
# ---

# %% [markdown]
# Printing a Comma-Separated List of Items

# %%
print('Welcome', 'to', 'Python!')
# Out:
# Welcome to Python!

# %% [markdown]
# Printing Many Lines of Text with One Statement

# %%
print('Welcome\nto\n\nPython!')
# Out:
# Welcome
# to
#
# Python!

# %% [markdown]
# The following table shows some common escape sequences.![Picture1.png](data:image/png;base64,...)

# %% [markdown]
# Ignoring a Line Break in a Long String

# %%
print('this is a longer string, so we \
 split it over two lines')
# Out:
# this is a longer string, so we  split it over two lines

# %% [markdown]
# Printing the Value of an Expression

# %%
print('Sum is', 7 + 3)
# Out:
# Sum is 10

# %% [markdown]
# What does the following print statement display?
#
# **print('int(5.2)', 'truncates 5.2 to', int(5.2))**

# %%
print('int(5.2)', 'truncates 5.2 to', int(5.2))
# Out:
# int(5.2) truncates 5.2 to 5

# %% [markdown]
# Including Quotes in Strings

# %%
print('Display "hi" in quotes')
# Out:
# Display "hi" in quotes

# %%
print('Display \'hi\' in quotes')   #using the \' escape sequence:
# Out:
# Display 'hi' in quotes

# %%
print("Display the name O'Brien")
# Out:
# Display the name O'Brien

# %%
print("Display \"hi\" in quotes")
# Out:
# Display "hi" in quotes

# %% [markdown]
# To avoid using \' and \" inside strings, you can enclose such strings in triple quotes:

# %%
print("""Display "hi" and 'bye' in quotes""")
# Out:
# Display "hi" and 'bye' in quotes

# %% [markdown]
# Multiline Strings

# %%
triple_quoted_string = """This is a triple-quoted
string that spans two lines"""

# %%
print(triple_quoted_string)
# Out:
# This is a triple-quoted
# string that spans two lines

# %%
triple_quoted_string
# Out:
# 'This is a triple-quoted\nstring that spans two lines'

# %%
print("""This is a lengthy
multiline string containing
a few lines \
of text""")
# Out:
# This is a lengthy
# multiline string containing
# a few lines of text

# %% [markdown]
# Precision Handling in Python

# %%
a = 3.4536475856

# %%
# using "%" to print value till 2 decimal places  
print ("The value of number till 2 decimal place(using %) is : ",end="") 
print ('%.2f' %a)
# Out:
# The value of number till 2 decimal place(using %) is : 3.45

# %%
# using "%" to print value till 4 decimal places  
print ("The value of number till 2 decimal place(using %) is : ",end="") 
print ('%.4f' %a)
# Out:
# The value of number till 2 decimal place(using %) is : 3.4536

# %% [markdown]
# # **Getting Input from the User**
# The built-in input function requests and obtains user input:

# %%
name = input("What's your name? ")
# Out:
# What's your name? shifat

# %%
print(name)
# Out:
# shifat

# %%
value1 = input('Enter first number: ')
value2 = input('Enter second number: ')
# Out:
# Enter first number: 30
# Enter second number: 40

# %%
total = value1 + value2
print(total)
# Out:
# 3040

# %%
type(total) #python takes input as a string we have to type cast the input
# Out:
# str

# %%
total = int(value1) + int(value2) #type casting to int format
print(total)
# Out:
# 70

# %% [markdown]
# Getting an Integer from the User by casting the input format

# %%
another_value = int(input('Enter another integer: '))
# Out:
# Enter another integer: 10

# %%
print(another_value)
# Out:
# 10

# %% [markdown]
# **Taking multiple input from the user**

# %%
a, b = input().split()
# Out:
# 10 20

# %%
print(a , b)
# Out:
# 10 20

# %%
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# # Solving Problem
#
# **Determining the Minimum and Maximum with Built-In Functions min and max**
#
#
# ---

# %%
number1 = int(input('Enter first integer: '))
number2 = int(input('Enter second integer: '))
number3 = int(input('Enter third integer: '))
# Out:
# Enter first integer: 20
# Enter second integer: 50
# Enter third integer: 100

# %%
min(number1,number2,number3)
# Out:
# 20

# %%
max(number1,number2,number3)
# Out:
# 100

# %% [markdown]
# #***Exercises***
#
# ---
#
#
#
# **Create the variables x = 2 and y = 3, then determine what
# each of the following statements displays:**
#
# *  print('x =', x)
# *  print('Value of', x, '+', x, 'is', (x + x))
# *  print('x =')
# *  print((x + y), '=', (y + x))
#
#
# ---
